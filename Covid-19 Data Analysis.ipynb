# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
#Dataframe
corona_virus_dataframe=pd.read_csv("full_grouped.csv")

# %%
corona_virus_dataframe
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 28793  2020-06-23  West Bank and Gaza       1169       3        442     724
# 28794  2020-06-23      Western Sahara         10       1          8       1
# 28795  2020-06-23               Yemen        992     261        356     375
# 28796  2020-06-23              Zambia       1477      18       1213     246
# 28797  2020-06-23            Zimbabwe        525       6         64     455
#
# ...

# %%
corona_virus_dataframe.shape
# Out:
# (28798, 10)

# %%
#col=corona_virus_dataframe['Date']
#ind=corona_virus_dataframe['Country/Region']
#val=['New cases']
corona_modified=corona_virus_dataframe.pivot(index='Country/Region',columns='Date',values='New cases')
corona_modified
# Out:
# Date                2020-01-22  2020-01-23  2020-01-24  2020-01-25  \
# Country/Region
# Afghanistan                  0           0           0           0
# Albania                      0           0           0           0
# Algeria                      0           0           0           0
# Andorra                      0           0           0           0
# Angola                       0           0           0           0
# ...                        ...         ...         ...         ...
# West Bank and Gaza           0           0           0           0
# Western Sahara               0           0           0           0
# Yemen                        0           0           0           0
# Zambia                       0           0           0           0
# Zimbabwe                     0           0           0           0
#
# Date                2020-01-26  2020-01-27  2020-01-28  2020-01-29  \
# Country/Region
# ...

# %%
total_cases=corona_modified.sum(axis=1)
total_cases
# Out:
# Country/Region
# Afghanistan           29481
# Albania                2047
# Algeria               12076
# Andorra                 855
# Angola                  189
#                       ...
# West Bank and Gaza     1169
# Western Sahara           10
# Yemen                   992
# Zambia                 1477
# Zimbabwe                531
# Length: 187, dtype: int64

# %%
corona_modified.drop(columns='Total Cases',inplace=True)

# %%
corona_modified.head(100)
# Out:
# Date            2020-01-22  2020-01-23  2020-01-24  2020-01-25  2020-01-26  \
# Country/Region
# Afghanistan              0           0           0           0           0
# Albania                  0           0           0           0           0
# Algeria                  0           0           0           0           0
# Andorra                  0           0           0           0           0
# Angola                   0           0           0           0           0
# ...                    ...         ...         ...         ...         ...
# Latvia                   0           0           0           0           0
# Lebanon                  0           0           0           0           0
# Lesotho                  0           0           0           0           0
# Liberia                  0           0           0           0           0
# Libya                    0           0           0           0           0
#
# ...

# %%
corona_india=corona_modified.loc['India'].plot()

corona_America=corona_modified.loc['US'].plot()
plt.style.use('seaborn')
plt.gcf().autofmt_xdate()

plt.legend()

# %%
corona_recovered=corona_virus_dataframe.pivot(index='Country/Region',columns='Date',values='New recovered')
corona_recovered
# Out:
# Date                2020-01-22  2020-01-23  2020-01-24  2020-01-25  \
# Country/Region
# Afghanistan                  0           0           0           0
# Albania                      0           0           0           0
# Algeria                      0           0           0           0
# Andorra                      0           0           0           0
# Angola                       0           0           0           0
# ...                        ...         ...         ...         ...
# West Bank and Gaza           0           0           0           0
# Western Sahara               0           0           0           0
# Yemen                        0           0           0           0
# Zambia                       0           0           0           0
# Zimbabwe                     0           0           0           0
#
# Date                2020-01-26  2020-01-27  2020-01-28  2020-01-29  \
# Country/Region
# ...

# %%
total_recovered_cases=corona_recovered.sum(axis=1)

# %%
total_recovered_cases
# Out:
# Country/Region
# Afghanistan           9260
# Albania               1195
# Algeria               8674
# Andorra                797
# Angola                  77
#                       ...
# West Bank and Gaza     442
# Western Sahara           8
# Yemen                  356
# Zambia                1213
# Zimbabwe                64
# Length: 187, dtype: int64

# %%
total_recovered_cases['India']
# Out:
# 258685

# %%
total_recovered_cases['US']
# Out:
# 647548

# %%
corona_recovered.loc['India'].plot()
corona_recovered.loc['US'].plot()
plt.gcf().autofmt_xdate()
plt.legend()

# %%
corona_recovered.loc['India'].diff().max()
# Out:
# 11453.0

# %%
corona_recovered.loc['US'].diff().max()
# Out:
# 47611.0

# %%
corona_deaths=corona_virus_dataframe.pivot(index='Country/Region',columns='Date',values='New deaths')

# %%
corona_deaths
# Out:
# Date                2020-01-22  2020-01-23  2020-01-24  2020-01-25  \
# Country/Region
# Afghanistan                  0           0           0           0
# Albania                      0           0           0           0
# Algeria                      0           0           0           0
# Andorra                      0           0           0           0
# Angola                       0           0           0           0
# ...                        ...         ...         ...         ...
# West Bank and Gaza           0           0           0           0
# Western Sahara               0           0           0           0
# Yemen                        0           0           0           0
# Zambia                       0           0           0           0
# Zimbabwe                     0           0           0           0
#
# Date                2020-01-26  2020-01-27  2020-01-28  2020-01-29  \
# Country/Region
# ...

# %%
total_death_cases=corona_deaths.sum(axis=1)

# %%
total_death_cases
# Out:
# Country/Region
# Afghanistan           618
# Albania                45
# Algeria               861
# Andorra                52
# Angola                 10
#                      ...
# West Bank and Gaza      3
# Western Sahara          1
# Yemen                 261
# Zambia                 18
# Zimbabwe                6
# Length: 187, dtype: int64

# %%
total_death_cases['India']
# Out:
# 14476

# %%
total_death_cases['US']
# Out:
# 121228

# %%
corona_deaths.loc['India'].plot()
corona_deaths.loc['US'].plot()
plt.gcf().autofmt_xdate()
plt.legend()

# %%
corona_deaths.loc['India'].diff().max()
# Out:
# 1623.0

# %%
corona_deaths.loc['US'].diff().max()
# Out:
# 903.0

# %%
population_dataframe=pd.read_csv("population.csv")
population_dataframe
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1438207241        0.39 %     5540090
# 1                     India         1377233523        0.99 %    13586631
# 2             United States          330610570        0.59 %     1937734
# 3                 Indonesia          272931713        1.07 %     2898047
# 4                  Pakistan          219992900        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4991        0.06 %           3
# 231        Falkland Islands               3458        3.05 %         103
# 232                    Niue               1624        0.68 %          11
# 233                 Tokelau               1354        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
population_dataframe_aggregated=population_dataframe.groupby("Country (or dependency)").sum()

# %%
population_dataframe_aggregated
# Out:
#                          Population (2020)  Net Change  Density (P/Km²)  \
# Country (or dependency)
# Afghanistan                       38742911      886592               60
# Albania                            2878420       -3120              105
# Algeria                           43685618      797990               18
# American Samoa                       55215        -121              276
# Andorra                              77240         123              164
# ...                                    ...         ...              ...
# Wallis & Futuna                      11276        -193               80
# Western Sahara                      594215       14876                2
# Yemen                             29687214      664042               56
# Zambia                            18273379      522925               25
# Zimbabwe                          14818157      217456               38
#
#                          Land Area (Km²)  Migrants (net)
# ...

# %%
population_dataframe_aggregated.drop(columns=['Net Change','Density (P/Km²)','Land Area (Km²)','Migrants (net)'],inplace=True)

# %%
population_dataframe_aggregated
# Out:
#                          Population (2020)
# Country (or dependency)
# Afghanistan                       38742911
# Albania                            2878420
# Algeria                           43685618
# American Samoa                       55215
# Andorra                              77240
# ...                                    ...
# Wallis & Futuna                      11276
# Western Sahara                      594215
# Yemen                             29687214
# Zambia                            18273379
# Zimbabwe                          14818157
#
# [235 rows x 1 columns]

# %%
population_india=population_dataframe_aggregated.loc['India']
population_india
# Out:
# Population (2020)    1377233523
# Name: India, dtype: int64

# %%
population_united_states=population_dataframe_aggregated.loc['United States']
population_united_states
# Out:
# Population (2020)    330610570
# Name: United States, dtype: int64

# %%
population_india-population_united_states
# Out:
# Population (2020)    1046622953
# dtype: int64
